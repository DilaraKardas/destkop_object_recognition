# %%
from google.colab import drive
import zipfile
import os

drive.mount('/content/drive')
zip_path = '/content/drive/MyDrive/colabDerinCalismalari/veriseti.zip'
extract_path = '/content/proje_verileri'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dosyalar başarıyla çıkarıldı!")
print(os.listdir(extract_path))
# Out:
# Mounted at /content/drive
# Dosyalar başarıyla çıkarıldı!
# ['test', 'train', 'README.roboflow.txt', 'valid', 'data.yaml', 'README.dataset.txt']

# %%
import yaml
with open(f'{extract_path}/data.yaml', 'r') as f:
    data_info = yaml.safe_load(f)

# kontrol amaçlı sınıf listesi çıkartılıyor
class_names = data_info['names']
print("Tespit edilen sınıflar:", class_names)
# Out:
# Tespit edilen sınıflar: ['fare', 'klavye', 'monitor', 'sandalye']

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')

model.train(
    data=f"{extract_path}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0 # gpu
)
# Out:
# ...
# Ultralytics 8.3.248 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files

files.download("runs/detect/train/weights/best.pt")

# %%
import shutil
shutil.copy("runs/detect/train/weights/best.pt", "/content/drive/MyDrive/colabDerinCalismalari/best_model.pt")
# Out:
# '/content/drive/MyDrive/colabDerinCalismalari/best_model.pt'
